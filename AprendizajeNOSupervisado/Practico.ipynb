# %%
import pandas
import numpy
import seaborn
import statistics
import matplotlib.pyplot as plt

# %%
dateparse = lambda x: pandas.to_datetime(x, utc=False, format='%Y-%m-%d',errors='coerce')

dataset = pandas.read_csv('datos_kunan_ok.csv', sep=';', 
    encoding='utf-8', parse_dates=['created_at'], date_parser=dateparse)

# %%
dataset.describe(include=['object'])
# Out:
#                                user_name                  user_screen_name  \
# count                               2000                              2000
# unique                               876                               877
# top     a9a7ef7b233aca755affeb84c12f8dc3  30082b1cbbd3bf9752446e2796ac12b4
# freq                                 168                               168
#
#                                                      text  \
# count                                                2000
# unique                                               1940
# top     RT @stpiindia: .@Oracle has big plans for #Ind...
# freq                                                    4
#
#                                     retweeted_status_text  \
# count                                                 351
# unique                                                329
# top     .@Oracle has big plans for #India: Safra Catz ...
# freq                                                    4
#
#        entities_hashtags_0_text entities_hashtags_1_text  \
# count                      1207                      950
# unique                      510                      398
# top                     BigData                      job
# freq                         67                       40
#
#        entities_hashtags_2_text entities_hashtags_3_text  lang  \
# count                       733                      553  2000
# unique                      308                      232     1
# top                    Shanghai                      Job    en
# freq                         34                       27  2000
#
#            user_location         place_country place_country_code  \
# count               1885                  1488               1488
# unique               383                    35                 17
# top     bengaluru, india  United Arab Emirates                 AE
# freq                 512                   431                453
#
#                     place_full_name          place_id place_name  \
# count                          1488              1488       1488
# unique                          156               128        150
# top     Dubai, United Arab Emirates  001907e868d06e24      Dubai
# freq                            348               368        349
#
#        place_place_type
# count              1488
# unique                1
# top               admin
# freq               1488

# %%
dataset[:5]
# Out:
#                    id          created_at                         user_name  \
# 0  843735213041684481 2017-03-20 08:05:25  3e2668770286a252f014ffb7efb84d20
# 1  848449270948786176 2017-04-02 08:17:24  f43189e2175960f7341523f453d24b54
# 2  864425770629967872 2017-05-16 10:22:18  60ff334bf9ff1cec020498dc3bccb850
# 3  842126376664719367 2017-03-15 21:32:28  410acf6127096fe91815150c4fe81bde
# 4  864793449350000640 2017-05-17 10:43:20  3c039e80a2c41b4094cc90a6841702c8
#
#                    user_screen_name  user_followers_count  \
# 0  8a078faadb878c0fad584d45fb06d819                   335
# 1  b5eebe95590544a2d84eae15e67b7358                   664
# 2  eef92d430d7370e729ccbf24efc03b07                  1899
# 3  b3718a72731dd6a11980bd9dabb3777d                  2223
# 4  403f5d69c2dbf5a9853e96f44dc3f2e4                   269
#
#                                                 text  retweet_count  \
# 0  #ASM Tour around the #KINGDOM for #Maintenance...              0
# 1  No floating @ Oracle Middle East https://t.co/...              0
# 2  #AMBA17 @K2Partnering  @SalesforceU great even...              0
# 3         Right ma cousine ! https://t.co/nOMVOjgo7x              0
# 4  Is #bigdata only a #buzzword ? #bigdata #data ...              0
#
#    favorite_count  retweeted_status_retweet_count  retweeted_status_id  \
# 0               0                             NaN                  NaN
# 1               0                             NaN                  NaN
# 2               0                             NaN                  NaN
# 3               0                             NaN                  NaN
# 4               0                             NaN                  NaN
#
#     ...                   user_location coordinates_coordinates_0  \
# 0   ...           jed | ryd | khb | dub                       NaN
# 1   ...       iphone: 0.000000,0.000000                 55.160722
# 2   ...                 españa, madrid                        NaN
# 3   ...                       dubai, dk                       NaN
# 4   ...     dubai, united arab emirates                       NaN
#
#   coordinates_coordinates_1           place_country place_country_code  \
# 0                       NaN     Emirati Arabi Uniti                 AE
# 1                 25.094102     Emirati Arabi Uniti                 AE
# 2                       NaN  Emiratos Árabes Unidos                 AE
# 3                       NaN     Emirats Arabes Unis                 AE
# 4                       NaN     Emirats Arabes Unis                 AE
#
#                  place_full_name          place_id place_name  \
# 0  دبي, الامارات العربية المتحدة  001907e868d06e24        دبي
# 1  دبي, الامارات العربية المتحدة  001907e868d06e24        دبي
# 2  Dubái, Emiratos Árabes Unidos  001907e868d06e24      Dubái
# 3     Dubaï, Emirats Arabes Unis  001907e868d06e24      Dubaï
# 4     Dubaï, Emirats Arabes Unis  001907e868d06e24      Dubaï
#
#    place_place_type  id_area
# 0             admin      NaN
# 1             admin      NaN
# 2             admin      NaN
# 3             admin      NaN
# 4             admin      NaN
#
# [5 rows x 27 columns]
